# %%
# 2025년 가을학기 강의 , 데이터분석(머신러닝) 실습 판다스 2, 비디오 강의듣으면 도움됨,2025_Fall_Data_A_Pandas_2.ipynb
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/03_subset_data.html# 의 강의 내용임, 4주차 실습강의
# !pip install pandas

# %%
import pandas as pd

# %%
titanic = pd.read_csv("d:/01_data/01_titanic_csv.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ages = titanic["Age"]

# %%
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(titanic["Age"])
# Out:
# pandas.core.series.Series

# %%
#titanic["Age"].shape
titanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
age_sex = titanic[["Age", "Sex"]]

# %%
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
titanic[["Age", "Sex"]].shape
# Out:
# (891, 2)

# %%
above_35 = titanic[titanic["Age"] > 35]

# %%
above_35.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 6       0     17463  51.8625   E46        S
# 11      0    113783  26.5500  C103        S
# 13      5    347082  31.2750   NaN        S
# 15      0    248706  16.0000   NaN        S

# %%
titanic["Age"] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
above_35.shape
# Out:
# (217, 12)

# %%
titanic.iloc[4:15, 2:5]
# Out:
#     Pclass                                               Name     Sex
# 4        3                           Allen, Mr. William Henry    male
# 5        3                                   Moran, Mr. James    male
# 6        1                            McCarthy, Mr. Timothy J    male
# 7        3                     Palsson, Master. Gosta Leonard    male
# 8        3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female

# %%
titanic.iloc[0:3, 3] = "anonymous"

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                     anonymous    male  22.0      1      0
# 1                                     anonymous  female  38.0      1      0
# 2                                     anonymous  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
# 4번째 강의, https://pandas.pydata.org/docs/getting_started/intro_tutorials/04_plotting.html
#air_quality = pd.read_csv("d:/01_data/01_air_quality_no2_csv.csv", index_col=0,parse_dates=True)
air_quality = pd.read_csv("d:/01_data/01_air_quality_no2_csv.csv", index_col=0, parse_dates=["datetime"])

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv("d:/01_data/01_air_quality_no2_csv.csv", parse_dates=True)

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality = pd.read_csv("d:/01_data/01_air_quality_no2_csv.csv", index_col=0, parse_dates=True)

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
air_quality.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality["station_paris"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
[
    method_name
    for method_name in dir(air_quality.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)

# %%
axs = air_quality.plot.area(figsize=(12, 4))

# %%
fig, axs = plt.subplots(figsize=(12, 4))

# %%
air_quality.plot.area(ax=axs)
# Out:
# <Axes: xlabel='datetime'>

# %%
axs.set_ylabel("NO$_2$ concentration")
# Out:
# Text(4.444444444444452, 0.5, 'NO$_2$ concentration')

# %%
axs = air_quality.plot.area(figsize=(12, 4))

# %%
df_20=air_quality.head(20)

# %%
df_20
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# 2019-05-07 07:00:00              NaN           72.4            26.0
# 2019-05-07 08:00:00              NaN           77.7            32.0
# 2019-05-07 09:00:00              NaN           67.9            32.0
# 2019-05-07 10:00:00              NaN           56.0            28.0
# 2019-05-07 11:00:00              NaN           34.5            21.0
# 2019-05-07 12:00:00              NaN           20.1            21.0
# 2019-05-07 13:00:00              NaN           13.0            18.0
# 2019-05-07 14:00:00              NaN           10.6            20.0
# ...

# %%
df_20.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
df_20.plot.box()
# Out:
# <Axes: >

# %%
df_20_london=df_20["station_london"]

# %%
df_20_london
# Out:
# datetime
# 2019-05-07 02:00:00    23.0
# 2019-05-07 03:00:00    19.0
# 2019-05-07 04:00:00    19.0
# 2019-05-07 05:00:00    16.0
# 2019-05-07 06:00:00     NaN
# 2019-05-07 07:00:00    26.0
# 2019-05-07 08:00:00    32.0
# 2019-05-07 09:00:00    32.0
# 2019-05-07 10:00:00    28.0
# 2019-05-07 11:00:00    21.0
# 2019-05-07 12:00:00    21.0
# 2019-05-07 13:00:00    18.0
# 2019-05-07 14:00:00    20.0
# 2019-05-07 15:00:00    18.0
# 2019-05-07 16:00:00    20.0
# 2019-05-07 17:00:00    20.0
# 2019-05-07 18:00:00    21.0
# 2019-05-07 19:00:00    20.0
# 2019-05-07 20:00:00    20.0
# 2019-05-07 21:00:00    24.0
# Name: station_london, dtype: float64

# %%
data_20=df_20["station_london"].value # Numpy data , 이것은 에러가 남. 아래처럼 시리즈 만기기
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 data_20=df_20["station_london"].value
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
type(df_20)
# Out:
# pandas.core.frame.DataFrame

# %%
df_21=df_20["station_london"]

# %%
type(df_21)
# Out:
# pandas.core.series.Series

# %%
data = df_21.tolist()

# %%
data
# Out:
# [23.0,
#  19.0,
#  19.0,
#  16.0,
#  nan,
#  26.0,
#  32.0,
#  32.0,
#  28.0,
#  21.0,
#  21.0,
#  18.0,
#  20.0,
#  18.0,
#  20.0,
#  20.0,
#  21.0,
#  20.0,
#  20.0,
#  24.0]

# %%
import pprint
pprint.pprint(data, width=1000)
# Out:
# [23.0, 19.0, 19.0, 16.0, nan, 26.0, 32.0, 32.0, 28.0, 21.0, 21.0, 18.0, 20.0, 18.0, 20.0, 20.0, 21.0, 20.0, 20.0, 24.0]

# %%
import os
os.getcwd()   # 현재 작업 중인 폴더(디렉토리) 경로 확인
# Out:
# 'C:\\Users\\dream'
